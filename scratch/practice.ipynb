# %%
class BankAccount():
    def __init__(self, customer_name, cust_id):
        self.customer_name = customer_name
        self.cus_id = cust_id
    def customer_info(self, customer_name):
        return f"customer name: {self.customer_name}, customer id: {self.cust_id}"

# %%
customer_one = BankAccount("Jane", 10071)
customer_two = BankAccount("Kim", 10072)

# %%
customer_two.customer_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 customer_two.customer_info()
#
# AttributeError: 'BankAccount' object has no attribute 'customer_info'
