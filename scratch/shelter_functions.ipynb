# %%
#Task 1
animals = ["Luna", "Biscuit", "Pepper", "Mango"]
print(animals)
print(len(animals))
print(type(animals))
# Out:
# ['Luna', 'Biscuit', 'Pepper', 'Mango']
# 4
# <class 'list'>

# %%
#Task 2
def greet_animal(animal_name):
    print(f"Welcome to the shelter, {animal_name}")

greet_animal("Jack")
greet_animal("Sparky")
greet_animal("Whiskers")
# Out:
# Welcome to the shelter, jack
# Welcome to the shelter, Sparky
# Welcome to the shelter, Whiskers

# %%
#Task 3
def adoption_fee(days_waiting):
    return days_waiting * 2

fee = adoption_fee(10)
print(fee)
# Out:
# 20

# %%
#Task 4
#count_paws value is not stored when run since it is print instead of return
def count_paws(num_animals):
    print(num_animals * 4)

total = count_paws(3)
print(total)

#count_paws stores total num_animals so will return animal count * 12
def count_paws(num_animals):
    return(num_animals * 4)

total = count_paws(3)
print(total)
# Out:
# 12
# None
# 12

# %%
#Task 5
print(adoption_fee(7))
# Out:
# 14

# %% [markdown]
# #Task 5 answer
#
# Because you can nest functions inside other functions to prevent having to re-write code.

# %%
#Task 6
def label_animal(name, species):
    print(name + " is a " + species)

label_animal("Luna", "Cat")
#A TypeError was triggered because an integer was used when a string was expected. 
#Type could be changed in function to convert type into string when value inserted.
#input in function could be changed from a int to a string, in this case 4 to "Cat"
# Out:
# Luna is a Cat

# %%
#Task 7
def animal_profile(name, days_waiting):
    fee = adoption_fee(days_waiting)
    return f"Name: {name} | Days waiting: {days_waiting} | Fee: ${fee}"

print(animal_profile("a", 2))
print(animal_profile("c", 6))
print(animal_profile("d", 7))
# Out:
# Name: a | Days waiting: 2 | Fee: $4
# Name: c | Days waiting: 6 | Fee: $12
# Name: d | Days waiting: 7 | Fee: $14

# %%
# Define player_summary
def player_summary(name, score, is_winner):
    if is_winner: True 
    return "Winner!"
    return "Not a winner."
    return name + "scored" + score + "points. Result:" + is_winner
    

# Call and print both results
print(player_summary(Alex, 42, True))
print(player_summary(Jordan, 31, False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 10
#       6     return name + "scored" + score + "points. Result:" + is_winner
#       9 # Call and print both results
# ---> 10 print(player_summary(Alex, 42, True))
#      11 print(player_summary(Jordan, 31, False))
#
# NameError: name 'Alex' is not defined

# %%
def process_score(score):
    doubled = score * 2
    capped = min(doubled, 100)
    return "Score: " + str(capped)

print(process_score(40))
# Out:
# Score: 80

# %%
# Define double_score
def double_score(score):
    return score * 2

# Define cap_score
def cap_score(score):
    return min(score, 100)

# Define label_score
def label_score(score):
    return "Score:" + str (score)

# Compose all three for a starting score of 40
# and print the result
print(double_score(40))
print(cap_score(40))
print(label_score(40))
# Out:
# 80
# 40
# Score:40
